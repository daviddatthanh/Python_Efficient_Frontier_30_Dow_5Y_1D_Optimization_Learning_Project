# %% [markdown]
# We will start by getting the closing data using yahoo_fin

# %%
import pandas as pd
import yahoo_fin
from yahoo_fin.stock_info import get_data, tickers_dow
import yahoo_fin.stock_info as si
from yahoo_fin import stock_info as si
# Out:
# Warning - Certain functionality
#              requires requests_html, which is not installed.
#
#              Install using:
#              pip install requests_html
#
#              After installation, you may have to restart your Python session.

# %%
#use https://arraythis.com/
#tickers = ["AAL", "AAPL", "AMD", "AMZN", "AVGO", "BA", "BK", "BTI", "CAT", "CME", "COF", "COST", "CRM", "CRWD", "CVX", "DASH", "DIA", "DIS", "FANG", "GOLD", "GS", "HAL", "IBM", "TSLA", "WM", "TXRH", "QQQ"]

# %%
# Get the list of Dow Jones tickers 
dow_tickers = tickers_dow()

# Get a list of S&P 500 tickers
#this should be wroking but it is not so we have to perform an altrnative method
#sp500_tickers = si.tickers_sp500()

import yfinance as yf
# Get the list of S&P 500 tickers
sp500_tickers = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]['Symbol'].tolist()

# %%
#all of the stocks in Dow is in the SP500
#Series let you do Boolean search, list does not 
pd.Series(dow_tickers)[pd.Series(dow_tickers).isin(pd.Series(sp500_tickers))]
# Out:
# 0     AAPL
# 1     AMGN
# 2     AMZN
# 3      AXP
# 4       BA
# 5      CAT
# 6      CRM
# 7     CSCO
# 8      CVX
# 9      DIS
# 10     DOW
# 11      GS
# 12      HD
# 13     HON
# 14     IBM
# 15    INTC
# 16     JNJ
# 17     JPM
# 18      KO
# 19     MCD
# 20     MMM
# 21     MRK
# 22    MSFT
# 23     NKE
# 24      PG
# 25     TRV
# 26     UNH
# 27       V
# 28      VZ
# 29     WMT
# dtype: object

# %%
sp500_tickers
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ACN',
#  'ADBE',
#  'AMD',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'ABNB',
#  'AKAM',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AMTM',
#  'AEE',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'AON',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ACGL',
#  'ADM',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'ADP',
#  'AZO',
#  'AVB',
#  'AVY',
#  'AXON',
#  'BKR',
#  'BALL',
#  'BAC',
#  'BAX',
#  'BDX',
#  'BRK.B',
#  'BBY',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BX',
#  'BK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BF.B',
#  'BLDR',
#  'BG',
#  'BXP',
#  'CHRW',
#  'CDNS',
#  'CZR',
#  'CPT',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CTLT',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
#  'COR',
#  'CNC',
# ...

# %%
ticker = 'TXRH'

# Check if the ticker is in the S&P 500 list
if ticker in sp500_tickers:
    print(f"{ticker} is in the S&P 500 list.")
else:
    print(f"{ticker} is not in the S&P 500 list.")

# Check if the ticker is in the Dow Jones list
if ticker in dow_tickers:
    print(f"{ticker} is in the Dow Jones list.")
else:
    print(f"{ticker} is not in the Dow Jones list.")
# Out:
# TXRH is not in the S&P 500 list.
# TXRH is not in the Dow Jones list.

# %%
#test the function
get_data("amzn", start_date="12/04/2009", end_date="12/04/2019", index_as_date = True, interval="1wk")['adjclose']
# Out:
# 2009-11-30     6.879000
# 2009-12-07     6.707500
# 2009-12-14     6.424000
# 2009-12-21     6.923500
# 2009-12-28     6.726000
#                 ...
# 2019-11-04    89.293999
# 2019-11-11    86.974503
# 2019-11-18    87.286003
# 2019-11-25    90.040001
# 2019-12-02    88.498001
# Name: adjclose, Length: 523, dtype: float64

# %%
#place the tickers in a dictionary
dow_historical_datas = {}

for ticker in dow_tickers: 
    dow_historical_datas[ticker] = get_data(ticker, start_date="08/30/2019", end_date="08/30/2024", index_as_date = True, interval="1d")['adjclose']

sp500_historical_datas = {}

#some of the ticker was delisted, so i have to use a try catch to continue after an error
for ticker in sp500_tickers: 
    try:
        # Try fetching the historical data for the ticker
        sp500_historical_datas[ticker] = get_data(ticker, start_date="08/30/2019", end_date="08/30/2024", index_as_date=True, interval="1d")['adjclose']
    except AssertionError as e:
        # If an error occurs, print the ticker and skip it
        print(f"Data for {ticker} not found: {e}")
        continue
    except KeyError as e: 
        # If an error occurs, print the ticker and skip it
        print(f"Data for {ticker} not found: {e}")
        continue
# Out:
# Data for AMTM not found: {'chart': {'result': None, 'error': {'code': 'Bad Request', 'description': "Data doesn't exist for startDate = 1567123200, endDate = 1724976000"}}}
# Data for BRK.B not found: {'chart': {'result': None, 'error': {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}}}
# Data for BF.B not found: 'timestamp'

# %%
#convert dictionaries into dataframes, super convenient
df_dow= pd.DataFrame(dow_historical_datas)
df_sp500= pd.DataFrame(sp500_historical_datas)

# %%
df_dow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2019-08-30 to 2024-08-29
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    1258 non-null   float64
#  1   AMGN    1258 non-null   float64
#  2   AMZN    1258 non-null   float64
#  3   AXP     1258 non-null   float64
#  4   BA      1258 non-null   float64
#  5   CAT     1258 non-null   float64
#  6   CRM     1258 non-null   float64
#  7   CSCO    1258 non-null   float64
#  8   CVX     1258 non-null   float64
#  9   DIS     1258 non-null   float64
#  10  DOW     1258 non-null   float64
#  11  GS      1258 non-null   float64
#  12  HD      1258 non-null   float64
#  13  HON     1258 non-null   float64
#  14  IBM     1258 non-null   float64
#  15  INTC    1258 non-null   float64
#  16  JNJ     1258 non-null   float64
#  17  JPM     1258 non-null   float64
#  18  KO      1258 non-null   float64
#  19  MCD     1258 non-null   float64
# ...

# %%
#exporting this as a csv file
df_dow.to_csv(r"Data\dow_raw_data.csv")
df_sp500.to_csv(r"Data\sp500_raw_data.csv")

# %%
df_dow.iloc[0:4,0:4]
# Out:
#                  AAPL        AMGN       AMZN         AXP
# 2019-08-30  50.496521  179.322464  88.814499  112.236336
# 2019-09-03  49.761093  176.657791  89.491997  109.653526
# 2019-09-04  50.605362  177.345474  90.030998  110.399460
# 2019-09-05  51.594780  178.488663  92.036003  112.516060
